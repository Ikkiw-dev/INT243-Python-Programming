# %%
import pandas as pd
import numpy as np

# %%
s = [1,2,3,'4',True,np.nan] #where np.nan is special data type (not considered as number)

# %%
#Convert to seies
s = pd.Series([1,2,3,'4',True,np.nan])
s
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4    True
# 5     NaN
# dtype: object

# %%
#indexing able in pandas
s[4]
# Out:
# True

# %%
t = pd.Series([1,2,3,4])
t.sum()
t.mean()
# Out:
# np.float64(2.5)

# %%
df = pd.DataFrame(
    {
        'a':[1,2,np.nan],
        'b':[3,4,'LalaLiao'],
        'c':pd.Timestamp("20260101"),
        'd':pd.Series(1,index=list(range(3)), dtype='int')
    }
)

df
# Out:
#      a         b          c  d
# 0  1.0         3 2026-01-01  1
# 1  2.0         4 2026-01-01  1
# 2  NaN  LalaLiao 2026-01-01  1

# %%
df['b']
# Out:
# 0           3
# 1           4
# 2    LalaLiao
# Name: b, dtype: object
