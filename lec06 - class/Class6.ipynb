# %%
#Answer key giftbox questions
gift_dims = [4,7,5]
wrapper_dims = [4,5,5]

n1 = gift_dims[0] #width
m1 = gift_dims[1] #length
h1 = gift_dims[2] #height

n2 = wrapper_dims[0]
m2 = wrapper_dims[1]
h2 = wrapper_dims[2]

compare = (
    (n1 <= n2 and m1 <= m2 and h1 <= h2) or 
    (n1 <= n2 and h1 <= m2 and m1 <= h2) or
    (m1 <= n2 and n1 <= m2 and h1 <= h2) or
    (m1 <= n2 and h1 <= m2 and n1 <= h2) or
    (h1 <= n2 and n1 <= m2 and m1 <= h1) or
    (h1 <= n2 and m1 <= m2 and n1 <= h2)
    )

if compare:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#Answer key for weapon factory
n = 25
total_invent = 10+8+3 #21
full_set = n // total_invent #inter devision concepts
swords = full_set 
shields = full_set
helmets = full_set

remains = n % total_invent
#prioritize making a sword, a shield and then a helmet
additional_sword = remains // 10
swords = swords + additional_sword

remains = remains - (additional_swords * 10)
#Update shields
additional_sheilds = remains // 8
shields = shields + additional_sword

remains = remains - (additional_sheilds * 10)

#Update helmets
additional_helmets = remains // 3
helmets = helmets + additional_helmets

remains = helmets - (additional_helmets * 10)
