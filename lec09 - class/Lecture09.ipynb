# %%
text = "Hello, world"
for i in text:
    print(i)
# Out:
# H
# e
# l
# l
# o
# ,
#
# w
# o
# r
# l
# d

# %%
print ("hello" in text)
print("ello" in text)
text2 = "This is also a greeting"
print(" a" in text2)
# Out:
# False
# True
# True

# %%
"word" not in text
# Out:
# True

# %%
#Part : String Operations
Textbase = "World"
x1 = "Hello {}".format(Textbase)
x2 = f"Hello {Textbase}"

print(x1)
print(x2)
# Out:
# Hello World
# Hello World

# %%
t1 = "World"
t2 = "Python"
x3 = " Hello {} {}".format(t1,t2)
x4 = f"Hello {t1} {t2}"
print(x3)
print(x4)
# Out:
# Hello World Python
# Hello World Python

# %%
# Out:
# 18
# Hello World Python
# 18
