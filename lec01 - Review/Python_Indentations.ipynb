# %%
Python Indentations

# %%
x = 10
if x == 10:
    print("Your input value is 10")
else:
    print("Your input value is not 10")
# Out:
# Your input value is 10

# %%
x = 10
if x == 10:
    print("Your input value is 10")
else:
    print("Your input value is not 10")
# Out:
#   Cell In[3], line 3
#     print("Your input value is 10")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
list1 = ["apple","banana","cherry"]
print(list1)
print(type(list1))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
list2 = list(("apple", "banana", "cherry"))
print(list2)
print(type(list2))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
list = ["A","B","C","D","E","F","G","H","I"]
list_rm = list.remove("F")
print(list)
list_pop = list.pop(2)
print(list)
print(type(list_pop))
list_cl = list.clear()
print(list)
print(type(list))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'G', 'H', 'I']
# ['A', 'B', 'D', 'E', 'G', 'H', 'I']
# <class 'str'>
# []
# <class 'list'>
