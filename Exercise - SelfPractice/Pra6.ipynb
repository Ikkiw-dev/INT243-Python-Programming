# %%
#Moodle 2 Review
# password validation
user = input("What's your username?")
passw = input("What's your password?")

if (user == "admin.sit") and (passw == "98765"):
    print("Granted")
else:
    print("Failed")
# Out:
# What's your username? admin.sit
# What's your password? 98765
# Granted

# %%
#2 from the given dictionary please find that how many people >500 using dictionary iterations
exam_scores = {
    "John": 712,
    "Sophia": 845,
    "Michael": 903,
    "Olivia": 678,
    "Daniel": 756,
    "Isabella": 889,
    "James": 971,
    "Mia": 604,
    "Ethan": 790,
    "Charlotte": 221
}

counter = 0
namepass = []
for name, score in exam_scores.items():
    if score > 500:
        counter += 1
        namepass.append(name)
print(counter)
# Out:
# 9

# %%
#3 write a script (nested loop)
for i in range(5):
    for j in range(1,7):
        if j % 2 == 0:
            print("O", end = " ")
        else:
            print("X", end = " ")
    print()
# Out:
# X O X O X O
# X O X O X O
# X O X O X O
# X O X O X O
# X O X O X O

# %%
#4 factor (mark as focused)

# %%
#5 There are two players play game

# %%
#6 Alphabet subsequence

# %%
#7 Star Link

# %%
#8 Neon signs
