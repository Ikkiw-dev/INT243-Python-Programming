# %%
###Lecture 02 Relational and logical expressions

# %%
x = (1-1!=0) or ('7'!=7)
print(x)
#False or True = True
# Out:
# True

# %%
#Input functions
user_input = input("Hello, Please key your name : ")
print(f"Hi, {user_input}")
print(type(user_input))
# Out:
# Hello, Please key your name :  67
# Hi, 67
# <class 'str'>

# %%
uin = input("Please enter your birth year (CE) : ")
print(f"You were born in {uin} CE.")

con_uin = int(uin)
byr = con_uin + 543
print(f"You were born in {byr} BE.")
# Out:
# Please enter your birth year (CE) :  2006
# You were born in 2006 CE.
# You were born in 2549 BE.

# %%
#Special Input Format (In Exam)
import sys #import lib sys

print("Enter your input.")
line = sys.stdin.readline().strip().split()

print(line)
# Out:
# Enter your input.
# []

# %%
#Quiz
A = (7 * 5) - 6 + 0 // (15 ** 2)
B = 7 * 5 - 6 + 0 // 15 ** 2
print(A)
print(B)
# Out:
# 29
# 29

# %%
print("statement 1")
if 1 > 3:
    print("statement 2")
if 1 > 0:
    print("statement 3")
else:
    print("statement 4")
print("statement 5")
# Out:
# statement 1
# statement 3
# statement 5

# %%
print("statement 1")
if 1 > 3:
    print("statement 2")
elif 1 > 0:
    print("statement 3")
else:
    print("statement 4")
print("statement 5")
# Out:
# statement 1
# statement 3
# statement 5

# %%
#While loop 
init = 1
while init <= 10:
    init += 1
print(init)
# Out:
# 11

# %%
#Task 1
i = 100
while i >= 1:
    print(i, end = " ") #set format
    i-=1

# %%
user_in = input("What is your actual age")

next6 = user_in + 6
print(f"Next 6 years you will be {next6} years old")
# Out:
# What is your actual age 19
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 user_in = input("What is your actual age")
# ----> 3 next6 = user_in + 6
#       4 print(f"Next 6 years you will be {next6} years old")
#
# TypeError: can only concatenate str (not "int") to str
