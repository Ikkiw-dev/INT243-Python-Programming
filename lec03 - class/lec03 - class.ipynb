# %%
#Lecture class 03 - More on loop manipulations

# %%
#Write a script to add a number while the input is non-negative
total = 0

while True:
    num = int(input("Enter your number : "))

    if num > 0: #check input that greater than 0
        total += num
    else:
        break
        #In case not have break, manual termination is required!
print(total)
# Out:
# Enter your number :  100
# Enter your number :  -1
# 100

# %%
acc = 0

for i in range(5):
    fav_num = int(input("What is your fav num : "))

    if fav_num < 0:
        break

    acc += fav_num
print(acc)
# Out:
# What is your fav num :  1
# What is your fav num :  10
# What is your fav num :  5
# What is your fav num :  -1
# 16

# %%
# TODO : Write a script print number 1-10, except 5

i = 0
while i < 10:
    i += 1
    if i == 5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
lst = list(range(1,11))

for i in lst:
    if
# Out:
#   Cell In[1], line 4
#     if
#        ^
# SyntaxError: invalid syntax

# %%
lst = [57, 12, 93, 45, 78, 34, 66, 23, 81, 9,
50, 88, 14, 72, 39, 6, 95, 28, 63, 41,
77, 19, 52, 85, 11, 32, 69, 24, 47, 92,
3, 56, 75, 18, 61, 27, 80, 53, 37, 90,
4, 73, 30, 67, 22, 58, 13, 96, 40, 84,
7, 48, 71, 20, 62, 35, 76, 10, 54, 87,
25, 64, 31, 70, 16, 59, 42, 91, 8, 97,
21, 60, 36, 79, 15, 55, 44, 83, 5, 98,
26, 65, 33, 74, 17, 49, 46, 82, 29, 99,
1, 68, 38, 86, 43, 100, 2, 89, 51, 94 ]

max_num = lst[0] #init maximum num

for i in lst:
    if i > max_num:
        max_num = i
print(max_num)

#avg = sum/n
total = 0
size = 0
for j in lst:
    total += j
    size += 1
print(f"total of this one is : {total}")
print(f"average of this one is : {total/size}")
# Out:
# 100
# total of this one is : 5050
# average of this one is : 50.5

# %%
#Exercise Moodle 1 : Fibonacci
num = int(input("What is your num : "))

x = 0
y = 1
for i in range(num):
    print(x, end = " ")
    temp = x + y
    x = y
    y = temp
# Out:
# What is your num :  5
# 0 1 1 2 3

# %%
#Exercise Moodle 1 : Fibonacci (List style)
num = int(input("What is your num : "))

fib_lst = [0,1]
for i in range(2, n-1):
    fib_lst.append(fib_lst[i-1] + fib_lst[i - 2])

# %%
#Exercise Moodle 2 : Accessibility (version Lecturer key)
if len(password) < 8:
    print("ACCESS DENIED")
elif " " in password:
    print("ACCESS DENIED")
elif "secret" not in password.lower():
    print("ACCESS DENIED")
else:
    count_letter = 0
    sum_number = 0

    letters = "abcdefghijklmnopqrstuvwxyz"
    num = "0123456789"

    for text in password:
        if text.lower() in letters:
            count_letter += 1
        elif text in num:
            sum_number += int(text)

    if (count_letter > 6) and (sum_number == 43):
        print("ACCESS GRANTED")
    else:
        print("ACCESS DENIED")
