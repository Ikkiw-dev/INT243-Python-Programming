# %%
#requests
import requests
import pandas as pd

# %%
target_url = "https://openlibrary.org/search.json"

# %%
requests.get(target_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 requests.get(target_url)
#
# NameError: name 'requests' is not defined
